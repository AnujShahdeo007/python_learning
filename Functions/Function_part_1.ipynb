# %%
def function_name():
    #statement

# %%
def greet():
    print("Helo, Welcome to Functions in Python!")

# %%
greet()
# Out:
# Helo, Welcome to Functions in Python!

# %%
def morning_routine():
    print("Wake up")
    print("Brush your teeth")
    print("Take a shower")
    print("Have breakfast")
    print("Go to work")

# %%
morning_routine()
# Out:
# Wake up
# Brush your teeth
# Take a shower
# Have breakfast
# Go to work

# %%
# Parameters and Arguments in Functions

def greet(name):
    print("Helo", name)

# %%
greet("Gaurav")
# Out:
# Helo Gaurav

# %%
def add(a,b):
    sum = a + b
    print("The sum is:", sum)

# %%
add(5,7)
# Out:
# The sum is: 12

# %%
add(10,15)
# Out:
# The sum is: 25

# %%
def login(username,password):
    if username == "admin" and password == "1234":
        print("Login Successful")
    else:
        print("Login Failed")

# %%
login("admin","123")
# Out:
# Login Failed

# %%
def calculate_discount(price, discount_percentage):
    discount= (price * discount_percentage)/100
    final_price= price - discount
    print("The final price after discount is:", final_price)

# %%
calculate_discount(5000, 10)
# Out:
# The final price after discount is: 4500.0

# %%
def process_file(file_name,file_type):
    print("Processing file:", file_name)
    print("File type is:", file_type)

# %%
process_file("data.csv", "csv")
# Out:
# Processing file: data.csv
# File type is: csv

# %%
import time 
start_time= time.time()
total=0
for i in range(1,1000001):
    total += i
end_time= time.time()
print("Sum is:", total)
print("Time taken to compute the sum:", end_time - start_time, "seconds")
# Out:
# Sum is: 500000500000
# Time taken to compute the sum: 0.09586882591247559 seconds

# %%
import time
def calculate_sum():
    total=0
    for i in range(1,1000001):
        total += i
    return total
start_time= time.time()
sum= calculate_sum()
end_time= time.time()
print("Sum is:", sum)
print("Time taken to compute the sum:", end_time - start_time, "seconds")
# Out:
# Sum is: 500000500000
# Time taken to compute the sum: 0.08233785629272461 seconds

# %%
# Return Values in Functions
def add(a,b):
    print(a+b)

result = add(3,4)
print("Result is:", result)  # This will print None because the function does not return
# Out:
# 7
# Result is: None

# %%
def add(a,b):
    return a + b

result = add(3,4)
print("Result is:", result)
# Out:
# Result is: 7

# %%
def add(a,b):
    return a + b

def sqaure(x):
    return x * x

# %%
result=sqaure(add(3,4))
print("Result is:", result)
# Out:
# Result is: 49

# %%
def function_name():
    #statement
    return Value1,value2,value3....

# %%
def calculate():
    return 10,20

# %%
a,b=calculate()
print("Result is:", a,b)
# Out:
# Result is: 10 20
