# %%
d={"a":1,"b":2,"c":3}

# d=dict(name="abc",age=25)

# pairs=[("a",1),("b",2)]
# d=dict(pairs)

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d["d"]
#
# KeyError: 'd'

# %%
d=dict(name="abc",age=25)

# %%
d
# Out:
# {'name': 'abc', 'age': 25}

# %%
d["name"]
# Out:
# 'abc'

# %%
d["age"]
# Out:
# 25

# %%
d.get("sala",0) # Always perfer to use get
# Out:
# 0

# %%
students={
    "name":"abc",
    "age":25,
    "city":"Pune"
}

# %%
#Add new key 

students["salaey"]=50000

# %%
students
# Out:
# {'name': 'abc', 'age': 25, 'city': 'Pune', 'salaey': 50000}

# %%
#update the value 

students["age"]=60

# %%
students
# Out:
# {'name': 'abc', 'age': 60, 'city': 'Pune', 'salaey': 50000}

# %%
#Remove Values 
# del 
del students["salaey"]

# %%
students
# Out:
# {'name': 'abc', 'age': 60, 'city': 'Pune'}

# %%
# pop
#popitem()
# clear

# %%
for k in students:
    print(k)
# Out:
# name
# age
# city

# %%
for v in students.values():
    print(v)
# Out:
# abc
# 60
# Pune

# %%
for k,v in students.items():
    print(k,v)
# Out:
# name abc
# age 60
# city Pune
