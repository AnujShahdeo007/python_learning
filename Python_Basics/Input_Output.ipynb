# %% [markdown]
# INPUT/OUTPUT
#
# Input means taking data from outside the program and storing it inside variables so the program can use it.
#
# Real-World Example
# 	•	ATM → you enter PIN
# 	•	Website → you enter username/password
# 	•	Python program → user types something

# %% [markdown]
# Output
#
# Output means showing result of the program to the user

# %% [markdown]
# Print() -> Built in function that sends data to the stdout ( standard output)-

# %%
print("hello")
# Out:
# hello

# %%
name="AWS"
print(name)
# Out:
# AWS

# %%
# Priniting Multiple Values
a=10
b=20
print(a,b)
# Out:
# 10 20

# %%
print(a,b,sep=",")
# Out:
# 10,20

# %%
# end keyword 
# end controls what happens at the end of the print statement
#end ="\n"  # default value of end is newline character \n

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
# print without newline
for i in range(5):
    print(i,end="|")
# Out:
# 0|1|2|3|4|

# %% [markdown]
# INPUT
#
# input() - Used to read the data from stdin

# %%
name=input()

# %%
name
# Out:
# '10'

# %%
name=input("Enter Name")

# %%
name
# Out:
# 'AWS'

# %%
a=input()
b=input()
print(a+b)
# Out:
# 1020

# %%
# Solution - type Casting

a=int(input())
b=int(input())
print(a+b)
# Out:
# 30

# %%
a=float(input())
b=float(input())
print(a+b)
# Out:
# 80.0

# %%
salary=float(input("Enter your salary: "))

# %%
salary
# Out:
# 10.0

# %%
a,b=input()

# %%
# Multiple Inputs 
a,b,c,d=input().split()

# %%
a
# Out:
# '10'

# %%
d
# Out:
# '40'

# %%
text="10,20,30"

# %%
print(text.split(","))
# Out:
# ['10', '20', '30']

# %%
text="a|b|c|d"
print(text.split("|"))
# Out:
# ['a', 'b', 'c', 'd']

# %%
a,b=map(int,input().split())

# %%
b
# Out:
# 20

# %%
nums=list(map(int,input().split()))

# %%
nums
# Out:
# [10, 20, 30, 40, 50]

# %%
# Output Formatting 

name="AWS"
age=25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is AWS and I am 25 years old.

# %%
print("Name:{}, Age:{}".format(name,age))
# Out:
# Name:AWS, Age:25

# %%
data={"name":"AWS","age":40}

# %%
print(data)
# Out:
# {'name': 'AWS', 'age': 40}
