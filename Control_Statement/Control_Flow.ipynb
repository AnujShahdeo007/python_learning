# %% [markdown]
# Control Statements
# ------------------------
# if-else
# Syntax
# if condition:
#     code_block
# else:
#     code block
#
# nested if
# loops
# break/continue

# %% [markdown]
# # Decision Making
#  if
#  if-else
#  if-elif-else
#  nested if
# # Looping
#  for
#  while
#
# # Loop Controls
#  break
#  continue
#  pass

# %%
if condition:
    statement(s)

# %%
age=15
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are not eligible to vote

# %%
age=15
age>18
# Out:
# False

# %%
age=15

# %%
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are not eligible to vote

# %%
if condition:
    code 
elif condition:
    code
else:
    code

# %%
marks=50

# %%
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Fail

# %%
x=10

if x>5:
    print("x is greater than 5")
if x>8:
    print("x is greater than 8")
if x>10:
    print("x is greater than 10")
if x>12:
    print("x is greater than 12") 
else:
    print("x is not greater than 12")
# Out:
# x is greater than 5
# x is greater than 8
# x is not greater than 12

# %%
if x>5:
    print("x is greater than 5")
elif x>8:
    print("x is greater than 8")
# Out:
# x is greater than 5

# %%
# Nested If-Else

if condition1:
    if condition2:
        statement(s)
    else:
        statement(s)
else:
    statement(s)

# %%
age=22
citizenship=True

# %%
if age>=18:
    if citizenship==True:
        print("You are eligible to vote")
    else:
        print("You must be a citizen to vote")
else:
    print("You are not eligible to vote")

# %%
username="adminh"
password="password1236"

if username=="admin":
    if password=="password123":
        print("Access granted")
    else:
        print("Incorrect password") 
else:
    print("Unknown user")
# Out:
# Unknown user

# %%
is_logged_in=True
account_active=True
item_in_stock=True
payment_successful=True
delivery_serviceable=False

# %%
if is_logged_in:
    print("User is logged in")
    if account_active:
        print("Account is active")
        if item_in_stock:
            print("Item is in stock")
            if payment_successful:
                print("Payment successful")
                if delivery_serviceable:
                    print("Order placed successfully!")
                else:
                    print("Delivery not available to your location.")
            else:
                print("Payment failed. Please try again.")
        else:
            print("Item is out of stock.")
    else:
        print("Account is inactive. Please contact support.")
else:
    print("Please log in to continue.")
# Out:
# User is logged in
# Account is active
# Item is in stock
# Payment successful
# Delivery not available to your location.

# %%
card=input("Did you insert the card? (yes/no): ").lower()

# %%
card
# Out:
# 'yes'

# %%
if card=="yes":
    pin=input("Enter your PIN: ")
    if pin=="1234":
        print("Access granted. You can proceed with your transaction.")
    else:
        print("Incorrect PIN. Access denied.")
else:
    print("Please insert your card to proceed.")
# Out:
# Access granted. You can proceed with your transaction.
