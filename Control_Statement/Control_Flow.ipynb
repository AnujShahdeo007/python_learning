# %% [markdown]
# Control Statements
# ------------------------
# if-else
# Syntax
# if condition:
#     code_block
# else:
#     code block
#
# nested if
# loops
# break/continue

# %% [markdown]
# # Decision Making
#  if
#  if-else
#  if-elif-else
#  nested if
# # Looping
#  for
#  while
#
# # Loop Controls
#  break
#  continue
#  pass

# %%
if condition:
    statement(s)

# %%
age=15
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are not eligible to vote

# %%
age=15
age>18
# Out:
# False

# %%
age=15

# %%
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are not eligible to vote

# %%
if condition:
    code 
elif condition:
    code
else:
    code

# %%
marks=90

# %%
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
elif marks>=60:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade A

# %%
x=10

if x>5:
    print("x is greater than 5")
if x>8:
    print("x is greater than 8")
if x>10:
    print("x is greater than 10")
if x>12:
    print("x is greater than 12") 
else:
    print("x is not greater than 12")
# Out:
# x is greater than 5
# x is greater than 8
# x is not greater than 12

# %%
if x>5:
    print("x is greater than 5")
elif x>8:
    print("x is greater than 8")
# Out:
# x is greater than 5

# %%
# Nested If-Else

if condition1:
    if condition2:
        statement(s)
    else:
        statement(s)
else:
    statement(s)

# %%
age=22
citizenship=True

# %%
if age>=18:
    if citizenship==True:
        print("You are eligible to vote")
    else:
        print("You must be a citizen to vote")
else:
    print("You are not eligible to vote")

# %%
username="adminh"
password="password1236"

if username=="admin":
    if password=="password123":
        print("Access granted")
    else:
        print("Incorrect password") 
else:
    print("Unknown user")
# Out:
# Unknown user

# %%
is_logged_in=True
account_active=True
item_in_stock=True
payment_successful=True
delivery_serviceable=False

# %%
if is_logged_in:
    print("User is logged in")
    if account_active:
        print("Account is active")
        if item_in_stock:
            print("Item is in stock")
            if payment_successful:
                print("Payment successful")
                if delivery_serviceable:
                    print("Order placed successfully!")
                else:
                    print("Delivery not available to your location.")
            else:
                print("Payment failed. Please try again.")
        else:
            print("Item is out of stock.")
    else:
        print("Account is inactive. Please contact support.")
else:
    print("Please log in to continue.")
# Out:
# User is logged in
# Account is active
# Item is in stock
# Payment successful
# Delivery not available to your location.

# %%
card=input("Did you insert the card? (yes/no): ").lower()

# %%
card
# Out:
# 'yes'

# %%
if card=="yes":
    pin=input("Enter your PIN: ")
    if pin=="1234":
        print("Access granted. You can proceed with your transaction.")
    else:
        print("Incorrect PIN. Access denied.")
else:
    print("Please insert your card to proceed.")
# Out:
# Access granted. You can proceed with your transaction.

# %%
if condition1:
    code 
elif condition2:
    code
elif condition3:
    code
else:
    code

# %%
age=16
citizen=False

# %%
if age>=18:
    if citizen:
        print("You are eligible to vote")
    else:
        print("You must be a citizen to vote")
else:
    print("You are Underage")
# Out:
# You are Underage

# %%
username="admin"
password="pass12"

# %%
if username=="admin":
    if password=="pass123":
        print("Login successful")
    else:
        print("Incorrect password")
else:
    print("Unknown user")
# Out:
# Incorrect password

# %%
is_logged_in=True
password_correct=True
account_active=True
user_role="user"

# %%
if is_logged_in:
    print("User is logged in")
    if password_correct:
        print("Password is correct")
        if account_active:
            print("Account is active")
            if user_role=="admin":
                print("Welcome, Admin! You have full access.")
            else:
                print("Welcome, User! You have limited access.")
        else:
            print("Account is inactive. Please contact support.")
    else:
        print("Incorrect password")      
else:
    print("Please log in to continue.")
# Out:
# User is logged in
# Password is correct
# Account is active
# Welcome, User! You have limited access.

# %% [markdown]
# # Looping
# - For and While

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
card_inserted = True

pin_entered = True

pin_correct = True

transaction_type_selected = True

transaction_type = "withdrawal"

amount = 5000  # Example withdrawal amount

# %%
ATM = 10000
if ATM:
    print ('Welcome')
    if ATM inserted
         print ('Please wait it is loading')
        if PIN entered:input('Enter your PIN: ')
            print ('Access granted')
            if PIN correct:
                print ('Select transaction type')
                if transaction type selected:
                    print ('Select your transaction')
                    if transaction is withdrawal: input('Enter amount of withdrawal: ')
                        print ('Please wait while your transaction is being processed')
                        if amount >= ATM
                            print ('Insufficient funds')
                        else:
                            print ('Transaction failed')
                else:
                    print ('No transaction type selected')
            else:
                print ('Incorrect PIN')
    else:
        print ('No PIN entered')
else:
    print ('ATM is loading')
# Out:
#   Cell In[32], line 2
#     if ATM:
#     ^
# IndentationError: unexpected indent

# %%
ATM = 10000

# %%
if ATM:
    print ('Welcome')
# Out:
# Welcome

# %%
card=input("Did you insert the card? (yes/no): ").lower()
pin=input("IS PIN is correct?(yes/no): ").lower()
account=input("Is your account active? (yes/no): ").lower()
balance=int(input("Enter account balance :  "))
withdraw_amount=int(input("Enter withdrawal amount : "))
atm_cash=int(input("Enter ATM cash available : "))
print("---------------------------------------------------------------")
print ("\n -------------------ATM Transaction-------------------\n")
print("---------------------------------------------------------------")

if card=="yes":
    print("Card inserted successfully.")
    if pin=="yes":
        print("Pin verified. Access granted.")
        if account=="yes":
            print("Account is active.")
            if balance>=withdraw_amount:
                print(f"Withdrawal of {withdraw_amount} Possible.")
                if atm_cash>=withdraw_amount:
                    print("ATM has sufficient cash. Please collect your money.")
                    print("Withdraw is sucessfull")
                    print("Remaining balance:", balance - withdraw_amount)
                    print("Please take your card.")
                else:
                    print("ATM does not have sufficient cash. Please try a smaller amount.")
            else:
                print("Insufficient account balance.")  
 
        else:
            print("Account is inactive. Please contact your bank.")
    else:
        print("Incorrect PIN. Access denied.")
else:
    print("Please insert your card to proceed.")
# Out:
# ---------------------------------------------------------------
#
#  -------------------ATM Transaction-------------------
#
# ---------------------------------------------------------------
# Card inserted successfully.
# Pin verified. Access granted.
# Account is active.
# Insufficient account balance.

# %%
# Out:
# 'yes'

# %% [markdown]
# # Loops
# students=["Rahul","Priya","neha"]
# for student in students:
#     print(student)

# %%
students=["Rahul","Priya","neha","a","b"]
for student in students:
    print(student)
# Out:
# Rahul
# Priya
# neha
# a
# b

# %%
password="1234"
entered="3456"
while entered!=password:
    entered=input("Enter the password: ")
print("Access granted")
# Out:
# Access granted
