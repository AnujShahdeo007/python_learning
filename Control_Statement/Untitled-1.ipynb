# %% [markdown]
# Control Statements
# ------------------------
# if-else
# nested if
# loops
# break/continue

# %% [markdown]
# # Decision Making
#  if
#  if-else
#  if-elif-else
#  nested if
# # Looping
#  for
#  while
#
# # Loop Controls
#  break
#  continue
#  pass

# %%
if condition:
    statement(s)

# %%
age=20
if age>=18:
    print("You are eligible to vote")
