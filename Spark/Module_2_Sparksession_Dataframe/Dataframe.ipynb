# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("MyFirstSparkApp") \
        .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/13 21:32:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.stop()

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
    .appName("MySparkSessionDemo")\
    .master("local[*]")\
    .config("spark.sql.shuffle.partitions","4")\
    .getOrCreate()

print("SparkSession created")
print("AppName",spark.sparkContext.appName)
print("master",spark.sparkContext.master)
print("Spark Version",spark.version)
# Out:
# SparkSession created
# AppName MySparkSessionDemo
# master local[*]
# Spark Version 3.5.4

# %%
data=[
    (1,"A",30,"Mumbai"),
    (2,"B",31,""),
    (3,"C",32,"Pune"),
    ("hello","D",33,"Bangalore"),
]
columns=["id","Name","age","City"]
df=spark.createDataFrame(data,columns)

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("city",StringType(),True)
])

# %%
data=[
    (1,"A",30,"Mumbai"),
    (2,"B",31,""),
    (3,"C",32,"Pune"),
    (4,"D",33,"Bangalore")
]
df3=spark.createDataFrame(data,schema)

# %%
df3.show()
# Out:
# +---+----+---+---------+
# | id|name|age|     city|
# +---+----+---+---------+
# |  1|   A| 30|   Mumbai|
# |  2|   B| 31|         |
# |  3|   C| 32|     Pune|
# |  4|   D| 33|Bangalore|
# +---+----+---+---------+

# %%
df3.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)

# %%
data=[
    [1,"A",30,"Mumbai"],
    [2,"B",31,"Delhi"]
]

column=["id","Name","age","City"]

df1=spark.createDataFrame(data,column)

# %%
df1.show()
# Out:
# +---+----+---+------+
# | id|Name|age|  City|
# +---+----+---+------+
# |  1|   A| 30|Mumbai|
# |  2|   B| 31| Delhi|
# +---+----+---+------+
