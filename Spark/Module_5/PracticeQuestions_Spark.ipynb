# %% [markdown]
# employees_df

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession.builder.appName("SparkPractice").getOrCreate()

employees_data = [
    (101, "Anuj", 10, 1001, "Data Engineer", 85000, "2022-01-10", "Mumbai", "India", 30, "M"),
    (102, "Riya", 10, 1001, "Data Engineer", 90000, "2021-03-15", "Mumbai", "India", 28, "F"),
    (103, "Vikas", 20, 1002, "Data Analyst", 65000, "2023-07-01", "Pune", "India", 26, "M"),
    (104, "Sneha", 20, 1002, "Data Analyst", 70000, "2020-11-21", "Pune", "India", 29, "F"),
    (105, "Amit", 30, 1003, "ML Engineer", 120000, "2019-06-30", "Bangalore", "India", 35, "M"),
    (106, "Pooja", 30, 1003, "ML Engineer", 115000, "2022-09-12", "Bangalore", "India", 31, "F"),
    (107, "Rahul", 40, 1004, "Manager", 150000, "2018-04-18", "Delhi", "India", 40, "M"),
    (108, "Neha", 40, 1004, "Manager", 145000, "2017-08-09", "Delhi", "India", 38, "F"),
    (109, "Karan", 50, 1005, "HR", 60000, "2021-12-01", "Chennai", "India", 32, "M"),
    (110, "Meera", 50, 1005, "HR", 62000, "2024-01-05", "Chennai", "India", 27, "F"),
    (111, "John", 60, 1006, "Finance Analyst", 95000, "2020-02-14", "New York", "USA", 36, "M"),
    (112, "Alice", 60, 1006, "Finance Analyst", 98000, "2022-05-20", "New York", "USA", 33, "F"),
    (113, "David", 70, 1007, "Software Engineer", 110000, "2019-09-17", "San Francisco", "USA", 34, "M"),
    (114, "Emma", 70, 1007, "Software Engineer", 108000, "2023-01-25", "San Francisco", "USA", 30, "F"),
    (115, "Chris", 80, 1008, "Consultant", None, "2023-10-10", "London", "UK", 37, "M"),
    (116, "Sophia", 80, 1008, "Consultant", 99000, "2022-02-22", "London", "UK", 29, "F"),
    (117, "Arjun", None, None, "Intern", 30000, "2024-06-01", "Hyderabad", "India", 23, "M"),
    (118, "Priya", 10, 1001, "Data Engineer", 92000, "2023-03-10", "Mumbai", "India", 27, "F"),
    (119, "Nisha", 20, 1002, "Data Analyst", None, "2024-02-15", "Pune", "India", 25, "F"),
    (120, "Rohit", 30, 1003, "ML Engineer", 125000, "2021-07-19", "Bangalore", "India", 33, "M")
]

employees_schema = StructType([
    StructField("emp_id", IntegerType(), True),
    StructField("emp_name", StringType(), True),
    StructField("dept_id", IntegerType(), True),
    StructField("manager_id", IntegerType(), True),
    StructField("job_role", StringType(), True),
    StructField("salary", IntegerType(), True),
    StructField("hire_date", StringType(), True),
    StructField("city", StringType(), True),
    StructField("country", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("gender", StringType(), True)
])

employees_df = spark.createDataFrame(employees_data, employees_schema) \
    .withColumn("hire_date", to_date("hire_date"))

employees_df.show()
employees_df.printSchema()

# %% [markdown]
# departments_df

# %%
departments_data = [
    (10, "Engineering", "India"),
    (20, "Analytics", "India"),
    (30, "AI", "India"),
    (40, "Management", "India"),
    (50, "HR", "India"),
    (60, "Finance", "USA"),
    (70, "Product", "USA"),
    (80, "Consulting", "UK"),
    (90, "Support", "Canada")
]

departments_schema = StructType([
    StructField("dept_id", IntegerType(), True),
    StructField("dept_name", StringType(), True),
    StructField("dept_country", StringType(), True)
])

departments_df = spark.createDataFrame(departments_data, departments_schema)

departments_df.show()

# %% [markdown]
# projects_df

# %%
projects_data = [
    (10001, "Customer360", 10, 1200000, "2024-01-01", "Active"),
    (10002, "FraudDetection", 30, 2500000, "2023-06-01", "Active"),
    (10003, "HRMS", 50, 400000, "2022-04-15", "Completed"),
    (10004, "Forecasting", 60, 850000, "2024-02-10", "Active"),
    (10005, "Recommendation", 30, 1800000, "2023-11-05", "On Hold"),
    (10006, "SelfServiceBI", 20, 650000, "2024-03-12", "Active"),
    (10007, "ERPUpgrade", 40, 900000, "2021-08-20", "Completed"),
    (10008, "CloudMigration", 10, 2200000, "2023-09-01", "Active"),
    (10009, "MobileApp", 70, 1500000, "2024-05-01", "Active"),
    (10010, "ClientAudit", 80, 300000, "2024-01-20", "Completed")
]

projects_schema = StructType([
    StructField("project_id", IntegerType(), True),
    StructField("project_name", StringType(), True),
    StructField("dept_id", IntegerType(), True),
    StructField("budget", IntegerType(), True),
    StructField("start_date", StringType(), True),
    StructField("status", StringType(), True)
])

projects_df = spark.createDataFrame(projects_data, projects_schema) \
    .withColumn("start_date", to_date("start_date"))

projects_df.show()

# %% [markdown]
# sales_df

# %%
sales_data = [
    (1, 101, "2024-01-05", "Laptop", 2, 70000, "North"),
    (2, 102, "2024-01-07", "Mouse", 5, 1000, "North"),
    (3, 103, "2024-01-10", "Keyboard", 3, 2000, "West"),
    (4, 104, "2024-01-11", "Laptop", 1, 72000, "West"),
    (5, 105, "2024-01-15", "Monitor", 2, 15000, "South"),
    (6, 106, "2024-01-18", "Laptop", 1, 71000, "South"),
    (7, 101, "2024-02-01", "Keyboard", 4, 2100, "North"),
    (8, 102, "2024-02-03", "Monitor", 1, 15500, "North"),
    (9, 103, "2024-02-05", "Mouse", 10, 950, "West"),
    (10, 104, "2024-02-06", "Laptop", 2, 73000, "West"),
    (11, 105, "2024-02-10", "Keyboard", 6, 2050, "South"),
    (12, 106, "2024-02-12", "Monitor", 2, 15200, "South"),
    (13, 111, "2024-02-15", "Laptop", 1, 75000, "East"),
    (14, 112, "2024-02-16", "Mouse", 8, 1100, "East"),
    (15, 113, "2024-02-20", "Keyboard", 5, 2200, "West"),
    (16, 114, "2024-02-22", "Laptop", 3, 74000, "West"),
    (17, 118, "2024-03-01", "Monitor", 1, 15800, "North"),
    (18, 119, "2024-03-05", "Mouse", 7, 1050, "West"),
    (19, 120, "2024-03-08", "Laptop", 2, 76000, "South"),
    (20, 116, "2024-03-10", "Keyboard", 4, 2300, "Europe")
]

sales_schema = StructType([
    StructField("sale_id", IntegerType(), True),
    StructField("emp_id", IntegerType(), True),
    StructField("sale_date", StringType(), True),
    StructField("product", StringType(), True),
    StructField("quantity", IntegerType(), True),
    StructField("unit_price", IntegerType(), True),
    StructField("region", StringType(), True)
])

sales_df = spark.createDataFrame(sales_data, sales_schema) \
    .withColumn("sale_date", to_date("sale_date")) \
    .withColumn("amount", col("quantity") * col("unit_price"))

sales_df.show()
sales_df.printSchema()

# %% [markdown]
# A. Basic Transformations and Filtering
#
# Show only emp_id, emp_name, and salary from employees_df.
# Filter employees whose salary is greater than 90000.
# Find employees from Mumbai.
# Find employees whose country is India and salary is greater than 80000.
# Find employees whose age is between 25 and 35.
# Find employees whose job role is either Data Engineer or ML Engineer.
# Find employees whose salary is null.
# Replace null salary with 0.
# Create a new column salary_band as High, Medium, Low based on salary.
# Create a new column experience_years using hire_date.
# Filter employees hired after 2022-01-01.
# Sort employees by salary ascending.
# Sort employees by salary descending, and age ascending.
# Remove duplicate job roles from employees_df.
# Show distinct cities where employees are working.
#
# B. String and Column Transformations
#
# Convert all employee names to uppercase.
# Convert job roles to lowercase.
# Extract first 3 characters of employee name.
# Create a new column combining city and country as location.
# Find employees whose names start with A.
# Find employees whose names end with a.
# Find employees whose job role contains Engineer.
# Replace spaces in job_role with _.
# Find length of each employee name.
# Create initials from employee names.
#
# C. Group By and Aggregation
#
# Find total salary by department.
# Find average salary by department.
# Find minimum and maximum salary by department.
# Count employees in each department.
# Find total salary by city.
# Find average age by country.
# Find count of employees by gender.
# Find total salary by gender and country.
# Find departments where average salary is greater than 90000.
# Find cities where employee count is more than 2.
# Find total salary and average salary by job role.
# Find total employees and total salary for each city.
# Find sum of salaries for India and USA separately.
# Find department-wise count of employees with non-null salary.
# Find count of unique job roles in each country.
#
# D. Order By and Aggregation Business Questions
#
# Find top 5 highest paid employees.
# Find 3 lowest paid employees ignoring null salaries.
# Find department with highest total salary.
# Find city with highest average salary.
# Find top 3 departments by employee count.
# Find highest paid employee in each country.
# Find lowest paid employee in each department.
# Find top 2 job roles by average salary.
# Find countries ordered by total salary descending.
# Find cities ordered by employee count descending.
#
# E. Join Questions
#
# Inner join employees and departments.
# Left join employees and departments.
# Find employees whose department is missing in departments_df.
# Find all departments that have no employees.
# Join employees with projects using dept_id.
# Find employee names with their department names.
# Find project names with department names.
# Find employees working in departments where project status is Active.
# Find employees and their project budgets.
# Find total project budget by department name.
# Find departments having more than one active project.
# Find employees who belong to departments that have no projects.
# Join sales_df with employees_df to get employee names for each sale.
# Find total sales amount by employee name.
# Find total sales amount by department name.
# Find top selling department based on sales amount.
# Find employees who never made a sale.
# Find sale records whose employee id does not exist in employees_df.
# Join employees, departments, and projects together.
# Find employee count and project count for each department.
#
# F. Sales Group By, Order By, Aggregation
#
# Find total sales amount by region.
# Find total sales amount by product.
# Find total quantity sold by product.
# Find average unit price by product.
# Find maximum sale amount by region.
# Find top 3 products by total sales amount.
# Find region-wise product sales amount.
# Find monthly sales amount.
# Find monthly sales quantity.
# Find daily sales trend sorted by date.
# Find average sale amount per employee.
# Find employee with highest total sales.
# Find region with lowest total sales.
# Find product with highest average unit price.
# Find count of sales transactions by region and product.
#
# G. Window Function Basics
#
# Assign row number to employees ordered by salary descending.
# Assign rank to employees based on salary.
# Assign dense rank to employees based on salary.
# Find top 3 highest paid employees using window function.
# Find top 2 employees in each department by salary.
# Find highest paid employee in each department using window.
# Find lowest paid employee in each country using window.
# Find cumulative salary by department ordered by hire date.
# Find running total of sales amount by region ordered by sale date.
# Find moving average of sales amount by region over current and previous 2 rows.
# Find previous salary in each department using lag.
# Find next salary in each department using lead.
# Compare employee salary with previous employee salary in same department.
# Find difference between current sale amount and previous sale amount by employee.
# Find latest hired employee in each department using window.

# %% [markdown]
# Advanced Questions
#
# These will help a lot in interviews.
#
# Find second highest salary in each department.
# Find third sale made by each employee.
# Find employees whose salary is above department average.
# Find employees whose salary is below overall average.
# Find departments where total project budget is greater than total employee salary.
# Find employees contributing to top 80 percent of department salary.
# Find month-over-month sales growth.
# Find top product in each region by total amount.
# Find employees with consecutive sales dates.
# Find manager-wise employee count.

# %% [markdown]
# Manager DataFrame for self join practice
#
# Use this small one also for self join and hierarchy.

# %%
managers_data = [
    (1001, "Manager_A"),
    (1002, "Manager_B"),
    (1003, "Manager_C"),
    (1004, "Manager_D"),
    (1005, "Manager_E"),
    (1006, "Manager_F"),
    (1007, "Manager_G"),
    (1008, "Manager_H")
]

managers_schema = StructType([
    StructField("manager_id", IntegerType(), True),
    StructField("manager_name", StringType(), True)
])

managers_df = spark.createDataFrame(managers_data, managers_schema)
managers_df.show()

# %% [markdown]
# Self-join practice
#
# Join employees with managers to get employee name and manager name.
# Find manager who has maximum employees.
# Find department-wise manager-wise employee count.
# Find employees without manager.
# Find manager-wise average salary.

# %% [markdown]
# Senario Based Questions

# %% [markdown]
# Scenario 1: Department Salary Analysis
#
# Find top 3 highest paid employees in each department along with department name.
# (join + window + order)
# Find department-wise total salary and percentage contribution of each department to overall salary.
# (groupBy + window)
# Find employees whose salary is greater than department average salary.
# (window)
#
#
# Scenario 2: Hiring Trend
# Find number of employees hired per year per department sorted by latest year.
# (groupBy + date + order)
# Find latest hired employee in each department.
# (window)
# Find employees hired in last 2 years and group them by city.
# (filter + groupBy)
#
# Scenario 3: Employee Performance (Sales)
# Find total sales amount per employee and rank them within each department.
# (join + groupBy + window)
# Find top selling employee in each region.
# (window)
# Find employees whose sales are above average sales in their region.
# (window)
#
#
# Scenario 4: Business KPI
#
# Find monthly sales trend (total amount) sorted by month.
# (date + groupBy)
# Find month-over-month growth percentage in sales.
# (window lag)
# Find region contributing highest revenue per month.
# (groupBy + window)
#
#
# Scenario 5: Product Analysis
# Find top 2 products in each region based on revenue.
# (window)
# Find product with highest average price per region.
# (groupBy + order)
# Find least sold product in each month.
# (window)
#
#
# Scenario 6: Department + Project Insights
# Find total project budget vs total salary per department.
# (join + groupBy)
# Find departments where project budget > employee salary.
# (filter)
# Find departments having more than 1 active project.
# (groupBy)
#
#
# Scenario 7: Missing / Data Quality
# Find employees without department or manager.
# (filter null)
# Find departments with no employees.
# (left join)
# Find employees who never made any sale.
# (left join + null filter)
#
# Scenario 8: Window Deep Practice
# Find running total of salary by department ordered by hire date.
# (window)
# Find difference between current and previous employee salary in same department.
# (lag)
# Find next hire in same department.
# (lead)
#
# Scenario 9: Ranking + Advanced
# Find second highest salary in each department.
# (dense_rank)
# Find top 20% employees by salary in each department.
# (ntile / percent_rank)
#
#
# Scenario 10: Real Business Mix
# Find top 3 departments by total sales amount.
# (join + groupBy + order)
# Find employee contribution % to department sales.
# (window)
# Find employees whose sales continuously increased (trend detection).
# (lag + logic)
# Find employees who worked on departments with highest project budget and also top sales performers.
# (multi join + window + filter)
